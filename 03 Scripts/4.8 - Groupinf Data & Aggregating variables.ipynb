# %% [markdown]
# # 4.8: Grouping Data & Aggregating Variables

# %% [markdown]
# ## Import the required libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# Import dataframes
path = r"D:\0 - Data Analytics\4 - Python fundamentals for Data Analysts\Instacart Basket Analisys"

# import dtaframe ords_prods_merge_V2.pkl
ords_prods_merge = pd.read_pickle(
    os.path.join(path, "02 Data", "Prepared Data", "ords_prods_merge_V2.pkl")
)

# create subset of df with first million rows
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                    NaN         True         196                  1
# 1                    NaN         True       14084                  2
# 2                    NaN         True       12427                  3
# 3                    NaN         True       26088                  4
# 4                    NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
#
#    department_id  prices _merge        price_label     busiest_day  \
# 0              7     9.0   both  Mid-range product  Regularly busy
# 1             16    12.5   both  Mid-range product  Regularly busy
# 2             19     4.4   both  Low-range product  Regularly busy
# 3             19     4.7   both  Low-range product  Regularly busy
# 4             17     1.0   both  Low-range product  Regularly busy
#
#      busiest_days busiest_period_of_day
# 0  Regularly busy        Average orders
# 1  Regularly busy        Average orders
# 2  Regularly busy        Average orders
# 3  Regularly busy        Average orders
# 4  Regularly busy        Average orders

# %% [markdown]
# ## Grouping Data

# %% [markdown]
# Steps to use groupby():
#
# - Split the data into groups based on some criteria.
# - Apply a function to each group separately.
# - Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# %% [markdown]
# ### groupby()
#
# this function will group a given dataframe by a given column.

# %%
df.groupby("product_name")

# %% [markdown]
# Now I need to aggregate the data to be able to see the results.

# %% [markdown]
# ### Aggregating Data with agg()

# %% [markdown]
# #### Performing Single Aggregation
#
# Calculate the mean of the “order_number” column grouped by the “department_id” column,to quickly compare the average number of orders per user across each Instacart department.

# %%
df.groupby("department_id").agg({"order_number": ["mean"]})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# There are some aggregations that can be conducted without use of the agg() function. For instance, the command above could be replaced with a command that uses the mean() function to achieve the same results:
df.groupby("department_id")["order_number"].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# difference in syntax between the two methods:
#
# - When using agg(), put the column you want to aggregate inside the parentheses of the agg() function as an argument.
# - When using mean() (or any other standard aggregation function), simply index the column with square brackets, then follow it with the function you want to use after the dot.

# %% [markdown]
# #### Dot Notation vs. Square Brackets
#
# df.groupby('department_id').order_number.mean() VS df.groupby("department_id")["order_number"].mean()

# %% [markdown]
# Using dot notation results in the same output as the function with brackets. Theoretically, then, you could use dot notation for your commands. However, there are a few reasons why we recommend sticking to square brackets as a general rule:
#
# - Visual Appearance: Square brackets stand out, and using them consistently will help those that may look at your code down the line understand your methods. If you suddenly decided to change to dot notation for certain operations, your colleagues wouldn’t know whether you were indexing or applying a function.
# - Default Role: Square brackets have no other role in Python beyond indexing. Dots, however, do (applying pandas functions, looking for certain attributes of a dataframe, etc.). When you start using dot notation for indexing, as well, Python has to work harder to understand what you’re telling it to do, which can make it slower.
#   In general, stick to brackets when it comes to indexing!

# %% [markdown]
# #### Performing Multiple Aggregation

# %%
# Aggregate and produce 'mean' and 'max' for 'order_number' column
df.groupby("department_id").agg({"order_number": ["mean", "min", "max"]})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# ### Aggregating Data with transform()
#
# Create loyalty flag:
#
# - First transform() to create a column with maximum frequency of 'order_number'
# - Then loc() creating a column with 'loyal' or 'not_loyal" flag
#
# Criteria for the flag:
#
# - If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# - If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# - If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %% [markdown]
# ##### Transform()
#
# - Split the data into groups based on the “user_id” column.
# - Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# - Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
ords_prods_merge["max_order"] = ords_prods_merge.groupby(["user_id"])[
    "order_number"
].transform(np.max)
# Out:
# C:\Users\oppre\AppData\Local\Temp\ipykernel_15380\3638217546.py:3: FutureWarning: The provided callable <function max at 0x0000026A47D256C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ].transform(np.max)

# %%
# check the results
pd.options.display.max_rows = None
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
# 50   2550362        1            10                   4                  8
# 51   2550362        1            10                   4                  8
# 52   2550362        1            10                   4                  8
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
# 62   2168274        2             1                   2                 11
# 63   2168274        2             1                   2                 11
# 64   2168274        2             1                   2                 11
# 65   2168274        2             1                   2                 11
# 66   2168274        2             1                   2                 11
# 67   2168274        2             1                   2                 11
# 68   2168274        2             1                   2                 11
# 69   2168274        2             1                   2                 11
# 70   2168274        2             1                   2                 11
# 71   2168274        2             1                   2                 11
# 72   1501582        2             2                   5                 10
# 73   1501582        2             2                   5                 10
# 74   1501582        2             2                   5                 10
# 75   1501582        2             2                   5                 10
# 76   1501582        2             2                   5                 10
# 77   1501582        2             2                   5                 10
# 78   1901567        2             3                   1                 10
# 79   1901567        2             3                   1                 10
# 80   1901567        2             3                   1                 10
# 81   1901567        2             3                   1                 10
# 82   1901567        2             3                   1                 10
# 83    738281        2             4                   2                 10
# 84    738281        2             4                   2                 10
# 85    738281        2             4                   2                 10
# 86    738281        2             4                   2                 10
# 87    738281        2             4                   2                 10
# 88    738281        2             4                   2                 10
# 89    738281        2             4                   2                 10
# 90    738281        2             4                   2                 10
# 91    738281        2             4                   2                 10
# 92    738281        2             4                   2                 10
# 93    738281        2             4                   2                 10
# 94    738281        2             4                   2                 10
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
# 5                    15.0        False         196                  1
# 6                    15.0        False       10258                  2
# 7                    15.0        False       12427                  3
# 8                    15.0        False       13176                  4
# 9                    15.0        False       26088                  5
# 10                   15.0        False       13032                  6
# 11                   21.0        False         196                  1
# 12                   21.0        False       12427                  2
# 13                   21.0        False       10258                  3
# 14                   21.0        False       25133                  4
# 15                   21.0        False       30450                  5
# 16                   29.0        False         196                  1
# 17                   29.0        False       12427                  2
# 18                   29.0        False       10258                  3
# 19                   29.0        False       25133                  4
# 20                   29.0        False       26405                  5
# 21                   28.0        False         196                  1
# 22                   28.0        False       12427                  2
# 23                   28.0        False       10258                  3
# 24                   28.0        False       25133                  4
# 25                   28.0        False       10326                  5
# 26                   28.0        False       17122                  6
# 27                   28.0        False       41787                  7
# 28                   28.0        False       13176                  8
# 29                   19.0        False         196                  1
# 30                   19.0        False       12427                  2
# 31                   19.0        False       10258                  3
# 32                   19.0        False       25133                  4
# 33                   20.0        False         196                  1
# 34                   20.0        False       10258                  2
# 35                   20.0        False       12427                  3
# 36                   20.0        False       25133                  4
# 37                   20.0        False       13032                  5
# 38                   14.0        False       12427                  1
# 39                   14.0        False         196                  2
# 40                   14.0        False       10258                  3
# 41                   14.0        False       25133                  4
# 42                   14.0        False       46149                  5
# 43                   14.0        False       49235                  6
# 44                    0.0        False       49235                  1
# 45                    0.0        False       46149                  2
# 46                    0.0        False       25133                  3
# 47                    0.0        False         196                  4
# 48                    0.0        False       10258                  5
# 49                    0.0        False       12427                  6
# 50                   30.0        False         196                  1
# 51                   30.0        False       46149                  2
# 52                   30.0        False       39657                  3
# 53                   30.0        False       38928                  4
# 54                   30.0        False       25133                  5
# 55                   30.0        False       10258                  6
# 56                   30.0        False       35951                  7
# 57                   30.0        False       13032                  8
# 58                   30.0        False       12427                  9
# 59                    NaN         True       32792                  1
# 60                    NaN         True       47766                  2
# 61                    NaN         True       20574                  3
# 62                    NaN         True       12000                  4
# 63                    NaN         True       48110                  5
# 64                    NaN         True       22474                  6
# 65                    NaN         True       16589                  7
# 66                    NaN         True       35917                  8
# 67                    NaN         True       27344                  9
# 68                    NaN         True       30489                 10
# 69                    NaN         True       27966                 11
# 70                    NaN         True       13176                 12
# 71                    NaN         True       45066                 13
# 72                   10.0        False       16797                  1
# 73                   10.0        False       47526                  2
# 74                   10.0        False        8479                  3
# 75                   10.0        False       47766                  4
# 76                   10.0        False       19051                  5
# 77                   10.0        False        8138                  6
# 78                    3.0        False       47766                  1
# 79                    3.0        False       32792                  2
# 80                    3.0        False       20574                  3
# 81                    3.0        False        7781                  4
# 82                    3.0        False       28874                  5
# 83                    8.0        False       49451                  1
# 84                    8.0        False       32792                  2
# 85                    8.0        False       32139                  3
# 86                    8.0        False       34688                  4
# 87                    8.0        False       36735                  5
# 88                    8.0        False       37646                  6
# 89                    8.0        False       22829                  7
# 90                    8.0        False       24852                  8
# 91                    8.0        False       47209                  9
# 92                    8.0        False       33276                 10
# 93                    8.0        False       45613                 11
# 94                    8.0        False        9681                 12
# 95                    8.0        False       21150                 13
# 96                    8.0        False       47144                  1
# 97                    8.0        False        5322                  2
# 98                    8.0        False       17224                  3
# 99                    8.0        False       38656                  4
#
#     reordered                                       product_name  aisle_id  \
# 0           0                                               Soda        77
# 1           0            Organic Unsweetened Vanilla Almond Milk        91
# 2           0                                Original Beef Jerky        23
# 3           0                         Aged White Cheddar Popcorn        23
# 4           0                   XL Pick-A-Size Paper Towel Rolls        54
# 5           1                                               Soda        77
# 6           0                                         Pistachios       117
# 7           1                                Original Beef Jerky        23
# 8           0                             Bag of Organic Bananas        24
# 9           1                         Aged White Cheddar Popcorn        23
# 10          0                              Cinnamon Toast Crunch       121
# 11          1                                               Soda        77
# 12          1                                Original Beef Jerky        23
# 13          1                                         Pistachios       117
# 14          0                              Organic String Cheese        21
# 15          0                               Creamy Almond Butter        88
# 16          1                                               Soda        77
# 17          1                                Original Beef Jerky        23
# 18          1                                         Pistachios       117
# 19          1                              Organic String Cheese        21
# 20          1                   XL Pick-A-Size Paper Towel Rolls        54
# 21          1                                               Soda        77
# 22          1                                Original Beef Jerky        23
# 23          1                                         Pistachios       117
# 24          1                              Organic String Cheese        21
# 25          0                                Organic Fuji Apples        24
# 26          0                                  Honeycrisp Apples        24
# 27          0                                     Bartlett Pears        24
# 28          1                             Bag of Organic Bananas        24
# 29          1                                               Soda        77
# 30          1                                Original Beef Jerky        23
# 31          1                                         Pistachios       117
# 32          1                              Organic String Cheese        21
# 33          1                                               Soda        77
# 34          1                                         Pistachios       117
# 35          1                                Original Beef Jerky        23
# 36          1                              Organic String Cheese        21
# 37          1                              Cinnamon Toast Crunch       121
# 38          1                                Original Beef Jerky        23
# 39          1                                               Soda        77
# 40          1                                         Pistachios       117
# 41          1                              Organic String Cheese        21
# 42          0                                  Zero Calorie Cola        77
# 43          0                                Organic Half & Half        53
# 44          1                                Organic Half & Half        53
# 45          1                                  Zero Calorie Cola        77
# 46          1                              Organic String Cheese        21
# 47          1                                               Soda        77
# 48          1                                         Pistachios       117
# 49          1                                Original Beef Jerky        23
# 50          1                                               Soda        77
# 51          1                                  Zero Calorie Cola        77
# 52          0                             Milk Chocolate Almonds        45
# 53          0                           0% Greek Strained Yogurt       120
# 54          1                              Organic String Cheese        21
# 55          1                                         Pistachios       117
# 56          0                    Organic Unsweetened Almond Milk        91
# 57          1                              Cinnamon Toast Crunch       121
# 58          1                                Original Beef Jerky        23
# 59          0                     Chipotle Beef & Pork Realstick        23
# 60          0                                    Organic Avocado        24
# 61          0                                     Roasted Turkey        96
# 62          0           Baked Organic Sea Salt Crunchy Pea Snack        72
# 63          0            Thin Stackers Brown Rice Lightly Salted        78
# 64          0                     Cheddar Bunnies Snack Crackers        78
# 65          0                                     Plantain Chips       107
# 66          0                   Organic Just Concord Grape Juice        98
# 67          0                               Uncured Genoa Salami        96
# 68          0                                    Original Hummus        67
# 69          0                                Organic Raspberries       123
# 70          0                             Bag of Organic Bananas        24
# 71          0                                   Honeycrisp Apple        24
# 72          0                                       Strawberries        24
# 73          0                                    Goat Cheese Log        21
# 74          0              Original Black Box Tablewater Cracker        78
# 75          1                                    Organic Avocado        24
# 76          0               Pita Chips, Simply Naked, Party Size       107
# 77          0                                 Traditional Hummus        67
# 78          1                                    Organic Avocado        24
# 79          1                     Chipotle Beef & Pork Realstick        23
# 80          1                                     Roasted Turkey        96
# 81          0  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 82          0                                 Carrot Ginger Soup         1
# 83          0                              Artichoke Spinach Dip        67
# 84          1                     Chipotle Beef & Pork Realstick        23
# 85          0                            Hommus Classic Original        67
# 86          0  Good Belly Probiotics Juice Drink Blueberry Ac...        31
# 87          0              Organic Roasted Sliced Chicken Breast        96
# 88          0                                Organic Gala Apples        24
# 89          0          Multigrain Flax Seeded Flatbread Crackers        78
# 90          0                                             Banana        24
# 91          0                               Organic Hass Avocado        24
# 92          0                              Kalamata Olive Spread        67
# 93          0                                           Pad Thai        38
# 94          0  Chicken Tikka Masala with Cumin Infused Basmat...        38
# 95          0                            Fire Grilled Steak Bowl        38
# 96          0     Unsweetened Original Almond Breeze Almond Milk        91
# 97          0  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98          0                   Oats & Honey Gluten Free Granola         3
# 99          0  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices _merge        price_label     busiest_day  \
# 0               7     9.0   both  Mid-range product  Regularly busy
# 1              16    12.5   both  Mid-range product  Regularly busy
# 2              19     4.4   both  Low-range product  Regularly busy
# 3              19     4.7   both  Low-range product  Regularly busy
# 4              17     1.0   both  Low-range product  Regularly busy
# 5               7     9.0   both  Mid-range product  Regularly busy
# 6              19     3.0   both  Low-range product  Regularly busy
# 7              19     4.4   both  Low-range product  Regularly busy
# 8               4    10.3   both  Mid-range product  Regularly busy
# 9              19     4.7   both  Low-range product  Regularly busy
# 10             14     4.0   both  Low-range product  Regularly busy
# 11              7     9.0   both  Mid-range product  Regularly busy
# 12             19     4.4   both  Low-range product  Regularly busy
# 13             19     3.0   both  Low-range product  Regularly busy
# 14             16     8.6   both  Mid-range product  Regularly busy
# 15             13     3.2   both  Low-range product  Regularly busy
# 16              7     9.0   both  Mid-range product      Least busy
# 17             19     4.4   both  Low-range product      Least busy
# 18             19     3.0   both  Low-range product      Least busy
# 19             16     8.6   both  Mid-range product      Least busy
# 20             17     1.0   both  Low-range product      Least busy
# 21              7     9.0   both  Mid-range product      Least busy
# 22             19     4.4   both  Low-range product      Least busy
# 23             19     3.0   both  Low-range product      Least busy
# 24             16     8.6   both  Mid-range product      Least busy
# 25              4     2.7   both  Low-range product      Least busy
# 26              4    14.0   both  Mid-range product      Least busy
# 27              4     5.0   both  Low-range product      Least busy
# 28              4    10.3   both  Mid-range product      Least busy
# 29              7     9.0   both  Mid-range product  Regularly busy
# 30             19     4.4   both  Low-range product  Regularly busy
# 31             19     3.0   both  Low-range product  Regularly busy
# 32             16     8.6   both  Mid-range product  Regularly busy
# 33              7     9.0   both  Mid-range product  Regularly busy
# 34             19     3.0   both  Low-range product  Regularly busy
# 35             19     4.4   both  Low-range product  Regularly busy
# 36             16     8.6   both  Mid-range product  Regularly busy
# 37             14     4.0   both  Low-range product  Regularly busy
# 38             19     4.4   both  Low-range product  Regularly busy
# 39              7     9.0   both  Mid-range product  Regularly busy
# 40             19     3.0   both  Low-range product  Regularly busy
# 41             16     8.6   both  Mid-range product  Regularly busy
# 42              7    13.4   both  Mid-range product  Regularly busy
# 43             16     1.8   both  Low-range product  Regularly busy
# 44             16     1.8   both  Low-range product  Regularly busy
# 45              7    13.4   both  Mid-range product  Regularly busy
# 46             16     8.6   both  Mid-range product  Regularly busy
# 47              7     9.0   both  Mid-range product  Regularly busy
# 48             19     3.0   both  Low-range product  Regularly busy
# 49             19     4.4   both  Low-range product  Regularly busy
# 50              7     9.0   both  Mid-range product      Least busy
# 51              7    13.4   both  Mid-range product      Least busy
# 52             19     6.8   both  Mid-range product      Least busy
# 53             16    12.6   both  Mid-range product      Least busy
# 54             16     8.6   both  Mid-range product      Least busy
# 55             19     3.0   both  Low-range product      Least busy
# 56             16     1.3   both  Low-range product      Least busy
# 57             14     4.0   both  Low-range product      Least busy
# 58             19     4.4   both  Low-range product      Least busy
# 59             19     5.2   both  Mid-range product  Regularly busy
# 60              4     6.3   both  Mid-range product  Regularly busy
# 61             20     2.3   both  Low-range product  Regularly busy
# 62             13    10.9   both  Mid-range product  Regularly busy
# 63             19     2.7   both  Low-range product  Regularly busy
# 64             19     4.1   both  Low-range product  Regularly busy
# 65             19     5.0   both  Low-range product  Regularly busy
# 66              7     9.4   both  Mid-range product  Regularly busy
# 67             20    14.8   both  Mid-range product  Regularly busy
# 68             20     7.5   both  Mid-range product  Regularly busy
# 69              4     4.4   both  Low-range product  Regularly busy
# 70              4    10.3   both  Mid-range product  Regularly busy
# 71              4     2.5   both  Low-range product  Regularly busy
# 72              4     1.3   both  Low-range product  Regularly busy
# 73             16     2.0   both  Low-range product  Regularly busy
# 74             19     3.5   both  Low-range product  Regularly busy
# 75              4     6.3   both  Mid-range product  Regularly busy
# 76             19     3.9   both  Low-range product  Regularly busy
# 77             20     2.0   both  Low-range product  Regularly busy
# 78              4     6.3   both  Mid-range product  Regularly busy
# 79             19     5.2   both  Mid-range product  Regularly busy
# 80             20     2.3   both  Low-range product  Regularly busy
# 81             16     6.6   both  Mid-range product  Regularly busy
# 82             20     6.2   both  Mid-range product  Regularly busy
# 83             20     7.1   both  Mid-range product  Regularly busy
# 84             19     5.2   both  Mid-range product  Regularly busy
# 85             20     7.5   both  Mid-range product  Regularly busy
# 86              7     5.8   both  Mid-range product  Regularly busy
# 87             20     8.9   both  Mid-range product  Regularly busy
# 88              4     9.1   both  Mid-range product  Regularly busy
# 89             19     5.5   both  Mid-range product  Regularly busy
# 90              4    12.3   both  Mid-range product  Regularly busy
# 91              4     4.0   both  Low-range product  Regularly busy
# 92             20    10.8   both  Mid-range product  Regularly busy
# 93              1    12.6   both  Mid-range product  Regularly busy
# 94              1     2.0   both  Low-range product  Regularly busy
# 95              1     5.9   both  Mid-range product  Regularly busy
# 96             16    14.0   both  Mid-range product  Regularly busy
# 97             19     2.9   both  Low-range product  Regularly busy
# 98             19     1.6   both  Low-range product  Regularly busy
# 99             19     3.4   both  Low-range product  Regularly busy
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1   Regularly busy        Average orders         10
# 2   Regularly busy        Average orders         10
# 3   Regularly busy        Average orders         10
# 4   Regularly busy        Average orders         10
# 5       Least busy        Average orders         10
# 6       Least busy        Average orders         10
# 7       Least busy        Average orders         10
# 8       Least busy        Average orders         10
# 9       Least busy        Average orders         10
# 10      Least busy        Average orders         10
# 11      Least busy           Most orders         10
# 12      Least busy           Most orders         10
# 13      Least busy           Most orders         10
# 14      Least busy           Most orders         10
# 15      Least busy           Most orders         10
# 16      Least busy        Average orders         10
# 17      Least busy        Average orders         10
# 18      Least busy        Average orders         10
# 19      Least busy        Average orders         10
# 20      Least busy        Average orders         10
# 21      Least busy           Most orders         10
# 22      Least busy           Most orders         10
# 23      Least busy           Most orders         10
# 24      Least busy           Most orders         10
# 25      Least busy           Most orders         10
# 26      Least busy           Most orders         10
# 27      Least busy           Most orders         10
# 28      Least busy           Most orders         10
# 29  Regularly busy        Average orders         10
# 30  Regularly busy        Average orders         10
# 31  Regularly busy        Average orders         10
# 32  Regularly busy        Average orders         10
# 33    Busiest days           Most orders         10
# 34    Busiest days           Most orders         10
# 35    Busiest days           Most orders         10
# 36    Busiest days           Most orders         10
# 37    Busiest days           Most orders         10
# 38    Busiest days           Most orders         10
# 39    Busiest days           Most orders         10
# 40    Busiest days           Most orders         10
# 41    Busiest days           Most orders         10
# 42    Busiest days           Most orders         10
# 43    Busiest days           Most orders         10
# 44    Busiest days           Most orders         10
# 45    Busiest days           Most orders         10
# 46    Busiest days           Most orders         10
# 47    Busiest days           Most orders         10
# 48    Busiest days           Most orders         10
# 49    Busiest days           Most orders         10
# 50      Least busy        Average orders         10
# 51      Least busy        Average orders         10
# 52      Least busy        Average orders         10
# 53      Least busy        Average orders         10
# 54      Least busy        Average orders         10
# 55      Least busy        Average orders         10
# 56      Least busy        Average orders         10
# 57      Least busy        Average orders         10
# 58      Least busy        Average orders         10
# 59  Regularly busy           Most orders         14
# 60  Regularly busy           Most orders         14
# 61  Regularly busy           Most orders         14
# 62  Regularly busy           Most orders         14
# 63  Regularly busy           Most orders         14
# 64  Regularly busy           Most orders         14
# 65  Regularly busy           Most orders         14
# 66  Regularly busy           Most orders         14
# 67  Regularly busy           Most orders         14
# 68  Regularly busy           Most orders         14
# 69  Regularly busy           Most orders         14
# 70  Regularly busy           Most orders         14
# 71  Regularly busy           Most orders         14
# 72  Regularly busy           Most orders         14
# 73  Regularly busy           Most orders         14
# 74  Regularly busy           Most orders         14
# 75  Regularly busy           Most orders         14
# 76  Regularly busy           Most orders         14
# 77  Regularly busy           Most orders         14
# 78    Busiest days           Most orders         14
# 79    Busiest days           Most orders         14
# 80    Busiest days           Most orders         14
# 81    Busiest days           Most orders         14
# 82    Busiest days           Most orders         14
# 83  Regularly busy           Most orders         14
# 84  Regularly busy           Most orders         14
# 85  Regularly busy           Most orders         14
# 86  Regularly busy           Most orders         14
# 87  Regularly busy           Most orders         14
# 88  Regularly busy           Most orders         14
# 89  Regularly busy           Most orders         14
# 90  Regularly busy           Most orders         14
# 91  Regularly busy           Most orders         14
# 92  Regularly busy           Most orders         14
# 93  Regularly busy           Most orders         14
# 94  Regularly busy           Most orders         14
# 95  Regularly busy           Most orders         14
# 96      Least busy           Most orders         14
# 97      Least busy           Most orders         14
# 98      Least busy           Most orders         14
# 99      Least busy           Most orders         14

# %% [markdown]
# ##### Deriving Columns with loc()
#
# Create Flag

# %%
# create a flag for the loyalty program with loc() function
ords_prods_merge.loc[ords_prods_merge["max_order"] > 40, "loyalty_flag"] = (
    "Loyal customer"
)
ords_prods_merge.loc[
    (ords_prods_merge["max_order"] <= 40) & (ords_prods_merge["max_order"] > 10),
    "loyalty_flag",
] = "Regular customer"
ords_prods_merge.loc[ords_prods_merge["max_order"] <= 10, "loyalty_flag"] = (
    "New customer"
)

# %%
# check the results
ords_prods_merge["loyalty_flag"].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# check the head() of specific columns, 'user_id', 'loyalty_flag', 'order_number'
ords_prods_merge[["user_id", "loyalty_flag", "order_number"]].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# # TASK 4.8

# %% [markdown]
# ## 1
#
# Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %% [markdown]
# Done

# %% [markdown]
# ## 2
#
# In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Find aggregated mean of order_number grouped by 'department_id'
ords_prods_merge.groupby("department_id").agg({"order_number": ["mean"]})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## 3
#
# Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
df.groupby("department_id").agg({"order_number": ["mean"]})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %% [markdown]
# ### Analysis of Differences Between Entire Dataframe and Subset Results
#
# The following observations can be made when comparing the mean `order_number` values across `department_id` for the entire dataframe and the subset:
#
# 1. **Overall Differences**:
#
#    - The mean `order_number` values in the subset are generally close to those in the full dataset, but some departments show slight variations.
#    - Some departments have a higher mean in the subset, while others show a decrease.
#
# 2. **Significant Deviations**:
#
#    - `department_id 3` shows the most noticeable increase in mean order number from `17.170395` (full) to `17.913544` (subset), indicating that the subset includes more frequent orders for this department.
#    - `department_id 1` has a considerable decrease from `15.457838` to `14.800024`, suggesting that the subset might have filtered out higher order numbers for this department.
#    - `department_id 20` shows an increase from `16.473447` to `17.138607`, implying a shift in the subset’s ordering pattern.
#    - `department_id 21` has a decrease from `22.902379` to `21.956893`, which, while not drastic, indicates a slightly different distribution in the subset.
#
# 3. **Minor Variations**:
#
#    - Some departments, such as `department_id 5` and `department_id 6`, show only minimal changes in their mean order number, suggesting that the subset does not significantly impact these departments.
#
# 4. **Potential Causes**:
#
#    - The subset might be filtered based on certain criteria, such as customer segments, product types, or specific time frames, leading to changes in order behavior.
#    - Variations in mean values can indicate differences in purchasing trends, where certain departments might have more recurrent customers in the subset.
#
# ### Conclusion:
#
# While the subset maintains a similar order distribution across most departments, there are a few notable shifts in mean order numbers. Departments such as `3`, `1`, and `20` exhibit meaningful differences, which could be investigated further to understand customer behavior in different scenarios.

# %% [markdown]
# ## 4
#
# Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# Done

# %% [markdown]
# ## 5
#
# The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Aggregate and produce 'mean','min' and 'max' of 'price' for 'loyalty_flag' column
ords_prods_merge.groupby("loyalty_flag").agg({"prices": ["mean", "min", "max"]})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# It looks like that Loyal customers tend to purchase lower costed items(10.4), while newer customers higher priced ones(13.3).
# Regular customers fit in the middle (12.5). There's something weird happening because all the custoemrs appear to experience a maximum purchase of 99999.0 this might be an outlier.

# %% [markdown]
# ## 6
#
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
#
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create an'avg_product_price' column for each user based on averge price across all their orders
ords_prods_merge["avg_product_price"] = ords_prods_merge.groupby(["user_id"])[
    "prices"
].transform(np.mean)
# Out:
# C:\Users\oppre\AppData\Local\Temp\ipykernel_15380\2907800482.py:4: FutureWarning: The provided callable <function mean at 0x0000026A47D260C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ].transform(np.mean)

# %%
# check the result of the new column  and user_id

ords_prods_merge[["user_id", "avg_product_price"]].head(60)
# Out:
#     user_id  avg_product_price
# 0         1           6.367797
# 1         1           6.367797
# 2         1           6.367797
# 3         1           6.367797
# 4         1           6.367797
# 5         1           6.367797
# 6         1           6.367797
# 7         1           6.367797
# 8         1           6.367797
# 9         1           6.367797
# 10        1           6.367797
# 11        1           6.367797
# 12        1           6.367797
# 13        1           6.367797
# 14        1           6.367797
# 15        1           6.367797
# 16        1           6.367797
# 17        1           6.367797
# 18        1           6.367797
# 19        1           6.367797
# 20        1           6.367797
# 21        1           6.367797
# 22        1           6.367797
# 23        1           6.367797
# 24        1           6.367797
# 25        1           6.367797
# 26        1           6.367797
# 27        1           6.367797
# 28        1           6.367797
# 29        1           6.367797
# 30        1           6.367797
# 31        1           6.367797
# 32        1           6.367797
# 33        1           6.367797
# 34        1           6.367797
# 35        1           6.367797
# 36        1           6.367797
# 37        1           6.367797
# 38        1           6.367797
# 39        1           6.367797
# 40        1           6.367797
# 41        1           6.367797
# 42        1           6.367797
# 43        1           6.367797
# 44        1           6.367797
# 45        1           6.367797
# 46        1           6.367797
# 47        1           6.367797
# 48        1           6.367797
# 49        1           6.367797
# 50        1           6.367797
# 51        1           6.367797
# 52        1           6.367797
# 53        1           6.367797
# 54        1           6.367797
# 55        1           6.367797
# 56        1           6.367797
# 57        1           6.367797
# 58        1           6.367797
# 59        2           7.515897

# %%
# Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”
ords_prods_merge.loc[ords_prods_merge["avg_product_price"] < 10, "spending_flag"] = (
    "Low spender"
)
ords_prods_merge.loc[ords_prods_merge["avg_product_price"] >= 10, "spending_flag"] = (
    "High spender"
)

# %%
# Examining the results
ords_prods_merge["spending_flag"].value_counts(dropna=False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ## 7
#
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# aggrgate and find the median in the “days_since_prior_order” column using square brackets notation

ords_prods_merge["median_between_orders"] = ords_prods_merge.groupby(["user_id"])[
    "days_since_last_order"
].transform(np.median)
# Out:
# C:\Users\oppre\AppData\Local\Temp\ipykernel_15380\4145879966.py:5: FutureWarning: The provided callable <function median at 0x0000026A47EBCD60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ].transform(np.median)

# %%
# check relevant columns 'user_id', 'days_since_last_order', 'median_between_orders'
ords_prods_merge[["user_id", "days_since_last_order", "median_between_orders"]].head(60)
# Out:
#     user_id  days_since_last_order  median_between_orders
# 0         1                    NaN                   20.5
# 1         1                    NaN                   20.5
# 2         1                    NaN                   20.5
# 3         1                    NaN                   20.5
# 4         1                    NaN                   20.5
# 5         1                   15.0                   20.5
# 6         1                   15.0                   20.5
# 7         1                   15.0                   20.5
# 8         1                   15.0                   20.5
# 9         1                   15.0                   20.5
# 10        1                   15.0                   20.5
# 11        1                   21.0                   20.5
# 12        1                   21.0                   20.5
# 13        1                   21.0                   20.5
# 14        1                   21.0                   20.5
# 15        1                   21.0                   20.5
# 16        1                   29.0                   20.5
# 17        1                   29.0                   20.5
# 18        1                   29.0                   20.5
# 19        1                   29.0                   20.5
# 20        1                   29.0                   20.5
# 21        1                   28.0                   20.5
# 22        1                   28.0                   20.5
# 23        1                   28.0                   20.5
# 24        1                   28.0                   20.5
# 25        1                   28.0                   20.5
# 26        1                   28.0                   20.5
# 27        1                   28.0                   20.5
# 28        1                   28.0                   20.5
# 29        1                   19.0                   20.5
# 30        1                   19.0                   20.5
# 31        1                   19.0                   20.5
# 32        1                   19.0                   20.5
# 33        1                   20.0                   20.5
# 34        1                   20.0                   20.5
# 35        1                   20.0                   20.5
# 36        1                   20.0                   20.5
# 37        1                   20.0                   20.5
# 38        1                   14.0                   20.5
# 39        1                   14.0                   20.5
# 40        1                   14.0                   20.5
# 41        1                   14.0                   20.5
# 42        1                   14.0                   20.5
# 43        1                   14.0                   20.5
# 44        1                    0.0                   20.5
# 45        1                    0.0                   20.5
# 46        1                    0.0                   20.5
# 47        1                    0.0                   20.5
# 48        1                    0.0                   20.5
# 49        1                    0.0                   20.5
# 50        1                   30.0                   20.5
# 51        1                   30.0                   20.5
# 52        1                   30.0                   20.5
# 53        1                   30.0                   20.5
# 54        1                   30.0                   20.5
# 55        1                   30.0                   20.5
# 56        1                   30.0                   20.5
# 57        1                   30.0                   20.5
# 58        1                   30.0                   20.5
# 59        2                    NaN                   13.0

# %%
# create order frequency flag for each user based on the median in the “days_since_prior_order” column using the following criteria:
# If the median of the days since a user’s last order is lower than 20, then label them as a “Frequent customer.”
# If the median is between 20 and 30, then label them as an “Regular customer.”
# If the median is higher than 30, then label them as an “Infrequent customer.”
ords_prods_merge.loc[
    ords_prods_merge["median_between_orders"] > 20, "order_frequency_flag"
] = "Frequent customer"

ords_prods_merge.loc[
    (ords_prods_merge["median_between_orders"] > 10)
    & (ords_prods_merge["median_between_orders"] <= 20),
    "order_frequency_flag",
] = "Regular customer"

ords_prods_merge.loc[
    ords_prods_merge["median_between_orders"] <= 10, "order_frequency_flag"
] = "Infrequent customer"

# %%
# check and count the results
ords_prods_merge["order_frequency_flag"].value_counts(dropna=False)
# Out:
# order_frequency_flag
# Infrequent customer    21559853
# Regular customer        7208564
# Frequent customer       3636437
# NaN                           5
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(["order_frequency_flag"]).user_id.nunique()
# Out:
# order_frequency_flag
# Frequent customer      59619
# Infrequent customer    86596
# Regular customer       59993
# Name: user_id, dtype: int64

# %%
# recheck the results of valuable columns
ords_prods_merge[
    [
        "user_id",
        "days_since_last_order",
        "median_between_orders",
        "order_frequency_flag",
    ]
].head(60)
# Out:
#     user_id  days_since_last_order  median_between_orders order_frequency_flag
# 0         1                    NaN                   20.5    Frequent customer
# 1         1                    NaN                   20.5    Frequent customer
# 2         1                    NaN                   20.5    Frequent customer
# 3         1                    NaN                   20.5    Frequent customer
# 4         1                    NaN                   20.5    Frequent customer
# 5         1                   15.0                   20.5    Frequent customer
# 6         1                   15.0                   20.5    Frequent customer
# 7         1                   15.0                   20.5    Frequent customer
# 8         1                   15.0                   20.5    Frequent customer
# 9         1                   15.0                   20.5    Frequent customer
# 10        1                   15.0                   20.5    Frequent customer
# 11        1                   21.0                   20.5    Frequent customer
# 12        1                   21.0                   20.5    Frequent customer
# 13        1                   21.0                   20.5    Frequent customer
# 14        1                   21.0                   20.5    Frequent customer
# 15        1                   21.0                   20.5    Frequent customer
# 16        1                   29.0                   20.5    Frequent customer
# 17        1                   29.0                   20.5    Frequent customer
# 18        1                   29.0                   20.5    Frequent customer
# 19        1                   29.0                   20.5    Frequent customer
# 20        1                   29.0                   20.5    Frequent customer
# 21        1                   28.0                   20.5    Frequent customer
# 22        1                   28.0                   20.5    Frequent customer
# 23        1                   28.0                   20.5    Frequent customer
# 24        1                   28.0                   20.5    Frequent customer
# 25        1                   28.0                   20.5    Frequent customer
# 26        1                   28.0                   20.5    Frequent customer
# 27        1                   28.0                   20.5    Frequent customer
# 28        1                   28.0                   20.5    Frequent customer
# 29        1                   19.0                   20.5    Frequent customer
# 30        1                   19.0                   20.5    Frequent customer
# 31        1                   19.0                   20.5    Frequent customer
# 32        1                   19.0                   20.5    Frequent customer
# 33        1                   20.0                   20.5    Frequent customer
# 34        1                   20.0                   20.5    Frequent customer
# 35        1                   20.0                   20.5    Frequent customer
# 36        1                   20.0                   20.5    Frequent customer
# 37        1                   20.0                   20.5    Frequent customer
# 38        1                   14.0                   20.5    Frequent customer
# 39        1                   14.0                   20.5    Frequent customer
# 40        1                   14.0                   20.5    Frequent customer
# 41        1                   14.0                   20.5    Frequent customer
# 42        1                   14.0                   20.5    Frequent customer
# 43        1                   14.0                   20.5    Frequent customer
# 44        1                    0.0                   20.5    Frequent customer
# 45        1                    0.0                   20.5    Frequent customer
# 46        1                    0.0                   20.5    Frequent customer
# 47        1                    0.0                   20.5    Frequent customer
# 48        1                    0.0                   20.5    Frequent customer
# 49        1                    0.0                   20.5    Frequent customer
# 50        1                   30.0                   20.5    Frequent customer
# 51        1                   30.0                   20.5    Frequent customer
# 52        1                   30.0                   20.5    Frequent customer
# 53        1                   30.0                   20.5    Frequent customer
# 54        1                   30.0                   20.5    Frequent customer
# 55        1                   30.0                   20.5    Frequent customer
# 56        1                   30.0                   20.5    Frequent customer
# 57        1                   30.0                   20.5    Frequent customer
# 58        1                   30.0                   20.5    Frequent customer
# 59        2                    NaN                   13.0     Regular customer

# %% [markdown]
# ## 8 Cleaning data removing outliers

# %%
# Replace the values over 100 with NaN with np.nan
ords_prods_merge.loc[ords_prods_merge["prices"] > 100, "prices"] = np.nan

# %% [markdown]
# ## 9
#
# Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Export dataframe
ords_prods_merge.to_pickle(
    os.path.join(path, "02 Data", "Prepared Data", "ords_prods_merge_V3.pkl")
)
